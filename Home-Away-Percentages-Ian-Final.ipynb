# %%
# Beginning notebook
# Import dependancies
from matplotlib import pyplot as plt
from scipy.stats import linregress
import numpy as np
from sklearn import datasets
import pandas as pd

# %%
raw_df = pd.read_csv("./edited_dataset.csv") # Call in csv data
raw_df['final_total'] = raw_df['score_home'] + raw_df['score_away'] # Create new columns
raw_df['True Spread']=0 # Create new columns
raw_df['Spread Outcome'] = 0 # Create new columns
raw_df['Total Outcome'] = 0 # Create new columns

# Rename all columns
raw_df = raw_df.rename(columns = {'schedule_date':'Date', 'schedule_season':'Season', 'schedule_week':'Week',
                                  'schedule_playoff':'Playoff Game', 'team_home':'Home Team','score_home':'Home Final',
                                  'score_away':'Away Final','team_away':'Away Team', 'team_favorite_id':'Favorite',
                                  'spread_favorite':'Spread', 'over_under_line':'Over/Under', 'stadium':'Location',
                                  'stadium_neutral':'Neutral Site','weather_temperature':'Temperature','weather_wind_mph':'Wind(MPH)',
                                  'weather_humidity':'Humidity', 'weather_detail':'Location Detail','final_total':'Total'
                                  
                                 })
# Reorder all columns
raw_df = raw_df[['Date', 'Season','Week','Playoff Game','Home Team','Home Final','True Spread','Away Final','Away Team',
                'Favorite','Spread','Over/Under','Total','Spread Outcome','Total Outcome','Location','Neutral Site','Temperature','Wind(MPH)','Humidity',
                'Location Detail']]

# %%
# Convert all home team column values to acronym to match favorite column
home_replaced = raw_df.replace({'Home Team' : {'New Orleans Saints':'NO', 'Miami Dolphins':'MIA','Chicago Bears':'CHI',
                                        'Buffalo Bills':'BUF','Houston Texans':'HOU', 'Jacksonville Jaguars':'JAX', 
                                        'New England Patriots':'NE','New York Giants':'NYG','Philadelphia Eagles':'PHI',
                                       'Pittsburgh Steelers':'PIT', 'Seattle Seahawks':'SEA','St. Louis Rams':'LAR',
                                       'Tampa Bay Buccaneers':'TB','Tennessee Titans':'TEN','Washington Redskins':'WAS',
                                       'Kansas City Chiefs':'KC','New York Jets':'NYJ','Atlanta Falcons':'ATL',
                                       'Carolina Panthers':'CAR','Cincinnati Bengals':'CIN','Cleveland Browns':'CLE',
                                       'Dallas Cowboys':'DAL','Denver Broncos':'DEN','Detroit Lions':'DET','Green Bay Packers':
                                       'GB','Indianapolis Colts':'IND','Minnesota Vikings':'MIN','Oakland Raiders':'OAK',
                                       'San Diego Chargers':'LAC','San Francisco 49ers':'SF','Arizona Cardinals':'ARI',
                                       'Baltimore Ravens':'BAL','Miami Dolphins':'MIA','Los Angeles Rams':'LAR',
                                       'Los Angeles Chargers':'LAC'}})

new_df = home_replaced.replace({'Away Team' : {'New Orleans Saints':'NO', 'Miami Dolphins':'MIA','Chicago Bears':'CHI',
                                        'Buffalo Bills':'BUF','Houston Texans':'HOU', 'Jacksonville Jaguars':'JAX', 
                                        'New England Patriots':'NE','New York Giants':'NYG','Philadelphia Eagles':'PHI',
                                       'Pittsburgh Steelers':'PIT', 'Seattle Seahawks':'SEA','St. Louis Rams':'LAR',
                                       'Tampa Bay Buccaneers':'TB','Tennessee Titans':'TEN','Washington Redskins':'WAS',
                                       'Kansas City Chiefs':'KC','New York Jets':'NYJ','Atlanta Falcons':'ATL',
                                       'Carolina Panthers':'CAR','Cincinnati Bengals':'CIN','Cleveland Browns':'CLE',
                                       'Dallas Cowboys':'DAL','Denver Broncos':'DEN','Detroit Lions':'DET','Green Bay Packers':
                                       'GB','Indianapolis Colts':'IND','Minnesota Vikings':'MIN','Oakland Raiders':'OAK',
                                       'San Diego Chargers':'LAC','San Francisco 49ers':'SF','Arizona Cardinals':'ARI',
                                       'Baltimore Ravens':'BAL','Miami Dolphins':'MIA','Los Angeles Rams':'LAR',
                                       'Los Angeles Chargers':'LAC'}})

# %%
# Solving for if the favorite covered
def func(row):
    if row['Favorite'] == row['Home Team']:
        return row['Home Final'] + row['Spread'] - row['Away Final']
    else:
        return row['Away Final'] + row['Spread'] - row['Home Final']
        
new_df['True Spread'] = new_df.apply(func, axis=1)

# %%
def spread(row):
    if row['True Spread'] > 0:
        return "FAV"
    elif row['True Spread'] < 0:
        return "DOG"
    else:
        return "PUSH"

new_df['Spread Outcome'] = new_df.apply(spread, axis=1)

# %%
def total(row):
    if row['Total'] < row['Over/Under']:
        return "UNDER"
    elif row['Total'] > row['Over/Under']:
        return "Over"
    else:
        return "PUSH"

new_df['Total Outcome'] = new_df.apply(total, axis=1)
final_df = pd.DataFrame(new_df)

# %%
final_df.head()
# Out:
#         Date  Season Week  Playoff Game Home Team  Home Final  True Spread  \
# 0   9/9/2010    2010    1         False        NO          14          0.0
# 1  9/12/2010    2010    1         False       BUF          10          2.0
# 2  9/12/2010    2010    1         False       CHI          19         -1.5
# 3  9/12/2010    2010    1         False       HOU          34        -11.0
# 4  9/12/2010    2010    1         False       JAX          24          4.0
#
#    Away Final Away Team Favorite  ...  Over/Under  Total  Spread Outcome  \
# 0           9       MIN       NO  ...        49.5     23            PUSH
# 1          15       MIA      MIA  ...        39.0     25             FAV
# 2          14       DET      CHI  ...        45.0     33             DOG
# 3          24       IND      IND  ...        48.0     58             DOG
# 4          17       DEN      JAX  ...        41.5     41             FAV
#
#   Total Outcome              Location Neutral Site  Temperature  Wind(MPH)  \
# 0         UNDER   Louisiana Superdome        False         72.0        0.0
# 1         UNDER  Ralph Wilson Stadium        False         64.0        7.0
# 2         UNDER         Soldier Field        False         75.0        1.0
# 3          Over       Reliant Stadium        False         89.0        5.0
# 4         UNDER        EverBank Field        False         91.0        1.0
#
#    Humidity   Location Detail
# 0       NaN              DOME
# 1      81.0               NaN
# 2      45.0               NaN
# 3       NaN  DOME (Open Roof)
# 4      67.0               NaN
#
# [5 rows x 21 columns]

# %%
def homeaway(row):
   if row['Home Final'] > row['Away Final']:
       return "Home Win"
   else:
       return "Away Win"
new_df['Home Away Winner'] = new_df.apply(homeaway, axis=1)
def homecover(row):
   if row['Home Team'] == row['Favorite'] and row['Spread Outcome'] == "FAV":
       return "Home Favorite Cover"
   elif row['Away Team'] == row['Favorite'] and row['Spread Outcome'] == "DOG":
           return "Home Dog Cover"
   elif row['Away Team'] == row['Favorite'] and row['Spread Outcome'] == "FAV":
           return "Away Favorite Cover"
   elif row['Home Team'] == row['Favorite'] and row['Spread Outcome'] == "DOG":
           return "Away Dog Cover"
   else:
    return "PUSH"
new_df['Location Cover'] = new_df.apply(homecover, axis=1)
new_df.columns
#print(new_df)

stadium = new_df.groupby(["Location"])
stadiumdf = stadium["Date", "Location", "Home Team", "Away Team","Favorite","Spread", "Home Final", "Away Final", "Location Cover", "Over/Under", "Total Outcome"]
stadiumdf.head()
# Out:
#             Date                             Location Home Team Away Team  \
# 0       9/9/2010                  Louisiana Superdome        NO       MIN
# 1      9/12/2010                 Ralph Wilson Stadium       BUF       MIA
# 2      9/12/2010                        Soldier Field       CHI       DET
# 3      9/12/2010                      Reliant Stadium       HOU       IND
# 4      9/12/2010                       EverBank Field       JAX       DEN
# 5      9/12/2010                     Gillette Stadium        NE       CIN
# 6      9/12/2010                      MetLife Stadium       NYG       CAR
# 7      9/12/2010              Lincoln Financial Field       PHI        GB
# 8      9/12/2010                          Heinz Field       PIT       ATL
# 9      9/12/2010                    CenturyLink Field       SEA        SF
# 10     9/12/2010                    Edward Jones Dome       LAR       ARI
# 11     9/12/2010                Raymond James Stadium        TB       CLE
# 12     9/12/2010                       Nissan Stadium       TEN       OAK
# 13     9/12/2010                          FedEx Field       WAS       DAL
# 14     9/13/2010                    Arrowhead Stadium        KC       LAC
# 15     9/13/2010                      MetLife Stadium       NYJ       BAL
# 16     9/19/2010                         Georgia Dome       ATL       ARI
# 17     9/19/2010              Bank of America Stadium       CAR        TB
# 18     9/19/2010                   Paul Brown Stadium       CIN       BAL
# 19     9/19/2010                  FirstEnergy Stadium       CLE        KC
# 20     9/19/2010                      Cowboys Stadium       DAL       CHI
# 21     9/19/2010  Sports Authority Field at Mile High       DEN       SEA
# 22     9/19/2010                           Ford Field       DET       PHI
# 23     9/19/2010                        Lambeau Field        GB       BUF
# 24     9/19/2010                    Lucas Oil Stadium       IND       NYG
# 25     9/19/2010                Mall of America Field       MIN       MIA
# 26     9/19/2010                      MetLife Stadium       NYJ        NE
# 27     9/19/2010                     Oakland Coliseum       OAK       LAR
# 28     9/19/2010                     Qualcomm Stadium       LAC       JAX
# 29     9/19/2010                       Nissan Stadium       TEN       PIT
# ...          ...                                  ...       ...       ...
# 1940   10/8/2017                    Hard Rock Stadium       MIA       TEN
# 1951  10/15/2017                          NRG Stadium       HOU       CLE
# 1955  10/15/2017              Mercedes-Benz Superdome        NO       DET
# 1959  10/16/2017                           LP Stadium       TEN       IND
# 1966  10/22/2017                       StubHub Center       LAC       DEN
# 1967  10/22/2017                   Twickenham Stadium       LAR       ARI
# 1968  10/22/2017                    Hard Rock Stadium       MIA       NYJ
# 1978  10/29/2017                   Twickenham Stadium       CLE       MIN
# 1981  10/29/2017              Mercedes-Benz Superdome        NO       CHI
# 1990   11/5/2017                         AT&T Stadium       DAL        KC
# 1993   11/5/2017                    Hard Rock Stadium       MIA       OAK
# 1994   11/5/2017              Mercedes-Benz Superdome        NO        TB
# 1999   11/5/2017                           LP Stadium       TEN       BAL
# 2012  11/12/2017                           LP Stadium       TEN       CIN
# 2018  11/19/2017                         AT&T Stadium       DAL       PHI
# 2022  11/19/2017                       StubHub Center       LAC       BUF
# 2023  11/19/2017                    Hard Rock Stadium       MIA        TB
# 2027  11/19/2017                       Estadio Azteca       OAK        NE
# 2054   12/3/2017                    Hard Rock Stadium       MIA       DEN
# 2153   9/16/2018                Mercedes-Benz Stadium       ATL       CAR
# 2170   9/23/2018                Mercedes-Benz Stadium       ATL        NO
# 2175   9/23/2018                      TIAA Bank Field       JAX       TEN
# 2186   9/30/2018                Mercedes-Benz Stadium       ATL       CIN
# 2191   9/30/2018                      TIAA Bank Field       JAX       NYJ
# 2215  10/14/2018                Mercedes-Benz Stadium       ATL        TB
# 2225  10/14/2018                    Tottenham Stadium       OAK       SEA
# 2233  10/21/2018                      TIAA Bank Field       JAX       HOU
# 2242  10/22/2018                Mercedes-Benz Stadium       ATL       NYG
# 2291  11/18/2018                      TIAA Bank Field       JAX       PIT
# 2318   12/2/2018                      TIAA Bank Field       JAX       IND
#
#      Favorite  Spread  Home Final  Away Final       Location Cover  \
# 0          NO    -5.0          14           9                 PUSH
# 1         MIA    -3.0          10          15  Away Favorite Cover
# 2         CHI    -6.5          19          14       Away Dog Cover
# 3         IND    -1.0          34          24       Home Dog Cover
# 4         JAX    -3.0          24          17  Home Favorite Cover
# 5          NE    -5.5          38          24  Home Favorite Cover
# 6         NYG    -6.0          31          18  Home Favorite Cover
# 7          GB    -3.0          20          27  Away Favorite Cover
# 8         ATL    -1.5          15           9       Home Dog Cover
# 9          SF    -3.0          31           6       Home Dog Cover
# 10        ARI    -3.0          13          17  Away Favorite Cover
# 11         TB    -2.5          17          14  Home Favorite Cover
# 12        TEN    -6.5          38          13  Home Favorite Cover
# 13        DAL    -3.0          13           7       Home Dog Cover
# 14        LAC    -4.0          21          14       Home Dog Cover
# 15        NYJ    -1.0           9          10       Away Dog Cover
# 16        ATL    -7.0          41           7  Home Favorite Cover
# 17        CAR    -4.0           7          20       Away Dog Cover
# 18        BAL    -3.0          15          10       Home Dog Cover
# 19        CLE    -3.0          14          16       Away Dog Cover
# 20        DAL    -7.0          20          27       Away Dog Cover
# 21        DEN    -3.5          31          14  Home Favorite Cover
# 22        PHI    -6.5          32          35       Home Dog Cover
# 23         GB   -13.0          34           7  Home Favorite Cover
# 24        IND    -4.0          38          14  Home Favorite Cover
# 25        MIN    -6.0          10          14       Away Dog Cover
# 26         NE    -3.0          28          14       Home Dog Cover
# 27        OAK    -3.0          16          14       Away Dog Cover
# 28        LAC    -7.0          38          13  Home Favorite Cover
# 29        TEN    -6.0          11          19       Away Dog Cover
# ...       ...     ...         ...         ...                  ...
# 1940      TEN    -3.0          16          10       Home Dog Cover
# 1951      HOU    -9.5          33          17  Home Favorite Cover
# 1955       NO    -4.0          52          38  Home Favorite Cover
# 1959      TEN    -7.0          36          22  Home Favorite Cover
# 1966      DEN    -1.5          21           0       Home Dog Cover
# 1967      LAR    -3.0          33           0  Home Favorite Cover
# 1968      MIA    -3.0          31          28                 PUSH
# 1978      MIN    -9.5          16          33  Away Favorite Cover
# 1981       NO    -9.0          20          12       Away Dog Cover
# 1990      DAL    -2.5          28          17  Home Favorite Cover
# 1993      OAK    -3.0          24          27                 PUSH
# 1994       NO    -7.0          30          10  Home Favorite Cover
# 1999      TEN    -3.0          23          20                 PUSH
# 2012      TEN    -4.5          24          20       Away Dog Cover
# 2018      PHI    -6.0           9          37  Away Favorite Cover
# 2022      LAC    -6.5          54          24  Home Favorite Cover
# 2023       TB    -1.0          20          30  Away Favorite Cover
# 2027       NE    -7.0           8          33  Away Favorite Cover
# 2054      DEN    -1.5          35           9       Home Dog Cover
# 2153      ATL    -5.5          31          24  Home Favorite Cover
# 2170      ATL    -1.5          37          43       Away Dog Cover
# 2175      JAX   -10.0           6           9       Away Dog Cover
# 2186      ATL    -3.5          36          37       Away Dog Cover
# 2191      JAX    -7.5          31          12  Home Favorite Cover
# 2215      ATL    -3.0          34          29  Home Favorite Cover
# 2225      SEA    -3.0           3          27  Away Favorite Cover
# 2233      JAX    -3.5           7          20       Away Dog Cover
# 2242      ATL    -4.0          23          20       Away Dog Cover
# 2291      PIT    -4.0          16          20                 PUSH
# 2318      IND    -4.0           6           0       Home Dog Cover
#
#       Over/Under Total Outcome
# 0           49.5         UNDER
# 1           39.0         UNDER
# 2           45.0         UNDER
# 3           48.0          Over
# 4           41.5         UNDER
# 5           45.0          Over
# 6           41.0          Over
# 7           48.0         UNDER
# 8           39.5         UNDER
# 9           37.0          PUSH
# 10          39.5         UNDER
# 11          37.0         UNDER
# 12          40.0          Over
# 13          40.0         UNDER
# 14          45.5         UNDER
# 15          36.5         UNDER
# 16          43.5          Over
# 17          37.5         UNDER
# 18          39.5         UNDER
# 19          38.0         UNDER
# 20          41.5          Over
# 21          41.0          Over
# 22          41.0          Over
# 23          43.0         UNDER
# 24          48.5          Over
# 25          41.0         UNDER
# 26          39.5          Over
# 27          37.5         UNDER
# 28          45.0          Over
# 29          37.0         UNDER
# ...          ...           ...
# 1940        43.5         UNDER
# 1951        47.0          Over
# 1955        49.5          Over
# 1959        46.0          Over
# 1966        41.0         UNDER
# 1967        46.0         UNDER
# 1968        39.5          Over
# 1978        38.0          Over
# 1981        47.5         UNDER
# 1990        53.0         UNDER
# 1993        44.5          Over
# 1994        54.0         UNDER
# 1999        41.0          Over
# 2012        40.5          Over
# 2018        48.0         UNDER
# 2022        41.0          Over
# 2023        42.0          Over
# 2027        54.5         UNDER
# 2054        39.5          Over
# 2153        44.0          Over
# 2170        54.0          Over
# 2175        39.0         UNDER
# 2186        52.5          Over
# 2191        40.5          Over
# 2215        57.0          Over
# 2225        48.0         UNDER
# 2233        42.5         UNDER
# 2242        53.0         UNDER
# 2291        47.0         UNDER
# 2318        45.5         UNDER
#
# [235 rows x 11 columns]

# %%
home_teams = new_df["Home Team"].unique()

# %%
def homeaway(row):
   if row['Home Final'] > row['Away Final']:
       return "Home Win"
   else:
       return "Away Win"
new_df['Home Away Winner'] = new_df.apply(homeaway, axis=1)
def homecover(row):
   if row['Home Team'] == row['Favorite'] and row['Spread Outcome'] == "FAV":
       return "Home Favorite Cover"
   elif row['Away Team'] == row['Favorite'] and row['Spread Outcome'] == "DOG":
           return "Home Dog Cover"
   elif row['Away Team'] == row['Favorite'] and row['Spread Outcome'] == "FAV":
           return "Away Favorite Cover"
   elif row['Home Team'] == row['Favorite'] and row['Spread Outcome'] == "DOG":
           return "Away Dog Cover"
   else:
    return "PUSH"
new_df['Location Cover'] = new_df.apply(homecover, axis=1)
new_df.columns
#print(new_df)
stadium = new_df.groupby(["Location Cover", "Home Team"]).count()['Date']
stadium_df = pd.DataFrame(stadium)
stadium_df.reset_index().head()

stadium_df

stadium_df.unstack(0)
# Out:
#                          Date                                     \
# Location Cover Away Dog Cover Away Favorite Cover Home Dog Cover
# Home Team
# ARI                      24.0                13.0           18.0
# ATL                      35.0                 3.0           10.0
# BAL                      36.0                 4.0            4.0
# BUF                      19.0                14.0           17.0
# CAR                      21.0                13.0           13.0
# CHI                      22.0                16.0           15.0
# CIN                      25.0                 8.0           13.0
# CLE                      17.0                25.0           21.0
# DAL                      36.0                 8.0           12.0
# DEN                      33.0                11.0           13.0
# DET                      21.0                14.0           14.0
# GB                       25.0                 5.0            3.0
# HOU                      25.0                13.0            7.0
# IND                      22.0                10.0           15.0
# JAX                      13.0                28.0           16.0
# KC                       34.0                 6.0           13.0
# LAC                      29.0                12.0            6.0
# LAR                      20.0                19.0           17.0
# MIA                      21.0                13.0           17.0
# MIN                      20.0                 7.0           17.0
# NE                       31.0                 NaN            3.0
# NO                       31.0                 2.0            6.0
# NYG                      26.0                14.0            9.0
# NYJ                      22.0                12.0           18.0
# OAK                      18.0                23.0           16.0
# PHI                      31.0                10.0            4.0
# PIT                      29.0                 3.0            7.0
# SEA                      23.0                 5.0           15.0
# SF                       24.0                13.0           14.0
# TB                       21.0                20.0           15.0
# TEN                      20.0                17.0           12.0
# WAS                      18.0                20.0           23.0
#
#
# Location Cover Home Favorite Cover PUSH
# Home Team
# ARI                           16.0  2.0
# ATL                           27.0  2.0
# BAL                           27.0  4.0
# BUF                           18.0  4.0
# CAR                           28.0  1.0
# CHI                           18.0  4.0
# CIN                           24.0  4.0
# CLE                            7.0  2.0
# DAL                           17.0  2.0
# DEN                           23.0  1.0
# DET                           23.0  NaN
# GB                            42.0  3.0
# HOU                           30.0  2.0
# IND                           25.0  3.0
# JAX                           12.0  4.0
# KC                            24.0  NaN
# LAC                           23.0  2.0
# LAR                           16.0  3.0
# MIA                           15.0  6.0
# MIN                           27.0  3.0
# NE                            52.0  4.0
# NO                            35.0  2.0
# NYG                           21.0  3.0
# NYJ                           18.0  2.0
# OAK                           13.0  2.0
# PHI                           30.0  1.0
# PIT                           34.0  4.0
# SEA                           33.0  2.0
# SF                            22.0  3.0
# TB                            13.0  3.0
# TEN                           16.0  7.0
# WAS                           10.0  3.0

# %%
new_df.groupby(["Location Cover", "Home Team"]).count()['Date']
home_team =stadium_df.unstack(0)
home_team.reset_index(inplace=True)
#This removed the 1st level columns
home_team.columns = home_team.columns.get_level_values(1)
home_team.fillna(0, inplace=True)
home_team["total"] =home_team["Away Dog Cover"] +home_team["Away Favorite Cover"] + home_team["Home Dog Cover"] + home_team["Home Favorite Cover"] + home_team["PUSH"]
home_team
# Out:
# Location Cover       Away Dog Cover  Away Favorite Cover  Home Dog Cover  \
# 0               ARI            24.0                 13.0            18.0
# 1               ATL            35.0                  3.0            10.0
# 2               BAL            36.0                  4.0             4.0
# 3               BUF            19.0                 14.0            17.0
# 4               CAR            21.0                 13.0            13.0
# 5               CHI            22.0                 16.0            15.0
# 6               CIN            25.0                  8.0            13.0
# 7               CLE            17.0                 25.0            21.0
# 8               DAL            36.0                  8.0            12.0
# 9               DEN            33.0                 11.0            13.0
# 10              DET            21.0                 14.0            14.0
# 11               GB            25.0                  5.0             3.0
# 12              HOU            25.0                 13.0             7.0
# 13              IND            22.0                 10.0            15.0
# 14              JAX            13.0                 28.0            16.0
# 15               KC            34.0                  6.0            13.0
# 16              LAC            29.0                 12.0             6.0
# 17              LAR            20.0                 19.0            17.0
# 18              MIA            21.0                 13.0            17.0
# 19              MIN            20.0                  7.0            17.0
# 20               NE            31.0                  0.0             3.0
# 21               NO            31.0                  2.0             6.0
# 22              NYG            26.0                 14.0             9.0
# 23              NYJ            22.0                 12.0            18.0
# 24              OAK            18.0                 23.0            16.0
# 25              PHI            31.0                 10.0             4.0
# 26              PIT            29.0                  3.0             7.0
# 27              SEA            23.0                  5.0            15.0
# 28               SF            24.0                 13.0            14.0
# 29               TB            21.0                 20.0            15.0
# 30              TEN            20.0                 17.0            12.0
# 31              WAS            18.0                 20.0            23.0
#
# Location Cover  Home Favorite Cover  PUSH  total
# 0                              16.0   2.0   73.0
# 1                              27.0   2.0   77.0
# 2                              27.0   4.0   75.0
# 3                              18.0   4.0   72.0
# 4                              28.0   1.0   76.0
# 5                              18.0   4.0   75.0
# 6                              24.0   4.0   74.0
# 7                               7.0   2.0   72.0
# 8                              17.0   2.0   75.0
# 9                              23.0   1.0   81.0
# 10                             23.0   0.0   72.0
# 11                             42.0   3.0   78.0
# 12                             30.0   2.0   77.0
# 13                             25.0   3.0   75.0
# 14                             12.0   4.0   73.0
# 15                             24.0   0.0   77.0
# 16                             23.0   2.0   72.0
# 17                             16.0   3.0   75.0
# 18                             15.0   6.0   72.0
# 19                             27.0   3.0   74.0
# 20                             52.0   4.0   90.0
# 21                             35.0   2.0   76.0
# 22                             21.0   3.0   73.0
# 23                             18.0   2.0   72.0
# 24                             13.0   2.0   72.0
# 25                             30.0   1.0   76.0
# 26                             34.0   4.0   77.0
# 27                             33.0   2.0   78.0
# 28                             22.0   3.0   76.0
# 29                             13.0   3.0   72.0
# 30                             16.0   7.0   72.0
# 31                             10.0   3.0   74.0

# %%
home_dog_perc = home_team["Home Dog Cover"] / (home_team["Away Favorite Cover"] + home_team["Home Dog Cover"]) * 100
home_fav_perc = home_team["Home Favorite Cover"] / (home_team["Away Dog Cover"] + home_team["Home Favorite Cover"]) * 100

# %%
cover_percents = pd.DataFrame({"Home Team": home_team[""],
                               "Home Dog %": home_dog_perc,
                               "Home Favorite %": home_fav_perc,
                               "Away Dog %": 100 - home_fav_perc,
                               "Away Favorite %": 100 - home_dog_perc})
cover_percents
# Out:
#    Home Team  Home Dog %  Home Favorite %  Away Dog %  Away Favorite %
# 0        ARI   58.064516        40.000000   60.000000        41.935484
# 1        ATL   76.923077        43.548387   56.451613        23.076923
# 2        BAL   50.000000        42.857143   57.142857        50.000000
# 3        BUF   54.838710        48.648649   51.351351        45.161290
# 4        CAR   50.000000        57.142857   42.857143        50.000000
# 5        CHI   48.387097        45.000000   55.000000        51.612903
# 6        CIN   61.904762        48.979592   51.020408        38.095238
# 7        CLE   45.652174        29.166667   70.833333        54.347826
# 8        DAL   60.000000        32.075472   67.924528        40.000000
# 9        DEN   54.166667        41.071429   58.928571        45.833333
# 10       DET   50.000000        52.272727   47.727273        50.000000
# 11        GB   37.500000        62.686567   37.313433        62.500000
# 12       HOU   35.000000        54.545455   45.454545        65.000000
# 13       IND   60.000000        53.191489   46.808511        40.000000
# 14       JAX   36.363636        48.000000   52.000000        63.636364
# 15        KC   68.421053        41.379310   58.620690        31.578947
# 16       LAC   33.333333        44.230769   55.769231        66.666667
# 17       LAR   47.222222        44.444444   55.555556        52.777778
# 18       MIA   56.666667        41.666667   58.333333        43.333333
# 19       MIN   70.833333        57.446809   42.553191        29.166667
# 20        NE  100.000000        62.650602   37.349398         0.000000
# 21        NO   75.000000        53.030303   46.969697        25.000000
# 22       NYG   39.130435        44.680851   55.319149        60.869565
# 23       NYJ   60.000000        45.000000   55.000000        40.000000
# 24       OAK   41.025641        41.935484   58.064516        58.974359
# 25       PHI   28.571429        49.180328   50.819672        71.428571
# 26       PIT   70.000000        53.968254   46.031746        30.000000
# 27       SEA   75.000000        58.928571   41.071429        25.000000
# 28        SF   51.851852        47.826087   52.173913        48.148148
# 29        TB   42.857143        38.235294   61.764706        57.142857
# 30       TEN   41.379310        44.444444   55.555556        58.620690
# 31       WAS   53.488372        35.714286   64.285714        46.511628

# %%
cover_percents2 = pd.DataFrame.round(cover_percents.copy(), 2)
cover_perc_columns = list(cover_percents2.columns)
for i in range(1, len(cover_perc_columns)):
    cover_percents2[cover_perc_columns[i]] = cover_percents2[cover_perc_columns[i]].astype(str) + '%'
cover_percents2
# Out:
#    Home Team Home Dog % Home Favorite % Away Dog % Away Favorite %
# 0        ARI     58.06%           40.0%      60.0%          41.94%
# 1        ATL     76.92%          43.55%     56.45%          23.08%
# 2        BAL      50.0%          42.86%     57.14%           50.0%
# 3        BUF     54.84%          48.65%     51.35%          45.16%
# 4        CAR      50.0%          57.14%     42.86%           50.0%
# 5        CHI     48.39%           45.0%      55.0%          51.61%
# 6        CIN      61.9%          48.98%     51.02%           38.1%
# 7        CLE     45.65%          29.17%     70.83%          54.35%
# 8        DAL      60.0%          32.08%     67.92%           40.0%
# 9        DEN     54.17%          41.07%     58.93%          45.83%
# 10       DET      50.0%          52.27%     47.73%           50.0%
# 11        GB      37.5%          62.69%     37.31%           62.5%
# 12       HOU      35.0%          54.55%     45.45%           65.0%
# 13       IND      60.0%          53.19%     46.81%           40.0%
# 14       JAX     36.36%           48.0%      52.0%          63.64%
# 15        KC     68.42%          41.38%     58.62%          31.58%
# 16       LAC     33.33%          44.23%     55.77%          66.67%
# 17       LAR     47.22%          44.44%     55.56%          52.78%
# 18       MIA     56.67%          41.67%     58.33%          43.33%
# 19       MIN     70.83%          57.45%     42.55%          29.17%
# 20        NE     100.0%          62.65%     37.35%            0.0%
# 21        NO      75.0%          53.03%     46.97%           25.0%
# 22       NYG     39.13%          44.68%     55.32%          60.87%
# 23       NYJ      60.0%           45.0%      55.0%           40.0%
# 24       OAK     41.03%          41.94%     58.06%          58.97%
# 25       PHI     28.57%          49.18%     50.82%          71.43%
# 26       PIT      70.0%          53.97%     46.03%           30.0%
# 27       SEA      75.0%          58.93%     41.07%           25.0%
# 28        SF     51.85%          47.83%     52.17%          48.15%
# 29        TB     42.86%          38.24%     61.76%          57.14%
# 30       TEN     41.38%          44.44%     55.56%          58.62%
# 31       WAS     53.49%          35.71%     64.29%          46.51%

# %%
a = cover_percents.iloc[0, 1]
b = cover_percents.iloc[0, 2]
c= cover_percents.iloc[0, 3]
d= cover_percents.iloc[0, 4]
# Washington individual stats
e = cover_percents.iloc[31, 1]
f = cover_percents.iloc[31, 2]
g = cover_percents.iloc[31, 3]
h = cover_percents.iloc[31, 4]
# New England individual stats
i = cover_percents.iloc[20, 1]
j = cover_percents.iloc[20, 2]
k = cover_percents.iloc[20, 3]
l = cover_percents.iloc[20, 4]
homedog = [a,e,i]
homefav = [b,f,j]
awaydog = [c,g,k]
awayfav = [d,h,l]
index = ['Arizona','Washington','New England']
df = pd.DataFrame({'Home Dog %': homedog,
                 'Home Fav %': homefav,
                 'Away Dog %': awaydog,
                 'Away Fav %': awayfav}, index=index)
chart = df.plot.bar(figsize=(20, 10), rot=0)

# %%
def homeaway(row):
   if row['Home Final'] > row['Away Final']:
       return "Home Win"
   else:
       return "Away Win"
new_df['Home Away Winner'] = new_df.apply(homeaway, axis=1)
def homecover(row):
   if row['Home Team'] == row['Favorite'] and row['Spread Outcome'] == "FAV":
       return "Home Favorite Cover"
   elif row['Away Team'] == row['Favorite'] and row['Spread Outcome'] == "DOG":
           return "Home Dog Cover"
   elif row['Away Team'] == row['Favorite'] and row['Spread Outcome'] == "FAV":
           return "Away Favorite Cover"
   elif row['Home Team'] == row['Favorite'] and row['Spread Outcome'] == "DOG":
           return "Away Dog Cover"
   else:
    return "PUSH"
new_df['Location Cover'] = new_df.apply(homecover, axis=1)
new_df.columns
#print(new_df)
stadium_away = new_df.groupby(["Location Cover", "Away Team"]).count()['Date']
stadium_away_df = pd.DataFrame(stadium_away)
stadium_away_df.reset_index().head()

stadium_away_df

stadium_away_df.unstack(0)
# Out:
#                          Date                                     \
# Location Cover Away Dog Cover Away Favorite Cover Home Dog Cover
# Away Team
# ARI                      24.0                11.0            9.0
# ATL                      18.0                17.0           18.0
# BAL                      27.0                14.0           16.0
# BUF                      27.0                 4.0            7.0
# CAR                      25.0                10.0           17.0
# CHI                      28.0                 9.0            8.0
# CIN                      27.0                13.0            9.0
# CLE                      28.0                 3.0            2.0
# DAL                      25.0                15.0           13.0
# DEN                      14.0                21.0           17.0
# DET                      24.0                 9.0           15.0
# GB                       16.0                23.0           21.0
# HOU                      21.0                11.0           10.0
# IND                      26.0                12.0           10.0
# JAX                      31.0                 4.0            5.0
# KC                       25.0                18.0            9.0
# LAC                      33.0                11.0           15.0
# LAR                      24.0                10.0            9.0
# MIA                      28.0                 6.0            7.0
# MIN                      27.0                10.0           10.0
# NE                       11.0                31.0           29.0
# NO                       23.0                17.0           22.0
# NYG                      30.0                10.0            9.0
# NYJ                      19.0                10.0            9.0
# OAK                      35.0                 3.0            5.0
# PHI                      24.0                15.0           19.0
# PIT                      19.0                18.0           26.0
# SEA                      21.0                17.0           20.0
# SF                       20.0                15.0           12.0
# TB                       36.0                 2.0            5.0
# TEN                      24.0                 6.0           13.0
# WAS                      32.0                 6.0            7.0
#
#
# Location Cover Home Favorite Cover PUSH
# Away Team
# ARI                           28.0  2.0
# ATL                           21.0  2.0
# BAL                           17.0  6.0
# BUF                           32.0  3.0
# CAR                           20.0  3.0
# CHI                           26.0  1.0
# CIN                           20.0  6.0
# CLE                           34.0  5.0
# DAL                           18.0  3.0
# DEN                           19.0  2.0
# DET                           24.0  3.0
# GB                            18.0  3.0
# HOU                           28.0  5.0
# IND                           26.0  4.0
# JAX                           30.0  4.0
# KC                            21.0  2.0
# LAC                           15.0  2.0
# LAR                           28.0  2.0
# MIA                           32.0  NaN
# MIN                           24.0  3.0
# NE                             4.0  1.0
# NO                            15.0  NaN
# NYG                           23.0  4.0
# NYJ                           30.0  7.0
# OAK                           29.0  1.0
# PHI                           17.0  NaN
# PIT                           13.0  2.0
# SEA                           18.0  5.0
# SF                            26.0  3.0
# TB                            27.0  2.0
# TEN                           29.0  2.0
# WAS                           27.0  NaN

# %%
away_team =stadium_away_df.unstack(0)

away_team.head(1)

away_team.reset_index(inplace=True)

#This removed the 1st level columns
away_team.columns = away_team.columns.get_level_values(1)

away_team.fillna(0, inplace=True)

away_team["Total"] =away_team["Away Dog Cover"] +away_team["Away Favorite Cover"] + away_team["Home Dog Cover"] + away_team["Home Favorite Cover"] + away_team["PUSH"]

away_team
# Out:
# Location Cover       Away Dog Cover  Away Favorite Cover  Home Dog Cover  \
# 0               ARI            24.0                 11.0             9.0
# 1               ATL            18.0                 17.0            18.0
# 2               BAL            27.0                 14.0            16.0
# 3               BUF            27.0                  4.0             7.0
# 4               CAR            25.0                 10.0            17.0
# 5               CHI            28.0                  9.0             8.0
# 6               CIN            27.0                 13.0             9.0
# 7               CLE            28.0                  3.0             2.0
# 8               DAL            25.0                 15.0            13.0
# 9               DEN            14.0                 21.0            17.0
# 10              DET            24.0                  9.0            15.0
# 11               GB            16.0                 23.0            21.0
# 12              HOU            21.0                 11.0            10.0
# 13              IND            26.0                 12.0            10.0
# 14              JAX            31.0                  4.0             5.0
# 15               KC            25.0                 18.0             9.0
# 16              LAC            33.0                 11.0            15.0
# 17              LAR            24.0                 10.0             9.0
# 18              MIA            28.0                  6.0             7.0
# 19              MIN            27.0                 10.0            10.0
# 20               NE            11.0                 31.0            29.0
# 21               NO            23.0                 17.0            22.0
# 22              NYG            30.0                 10.0             9.0
# 23              NYJ            19.0                 10.0             9.0
# 24              OAK            35.0                  3.0             5.0
# 25              PHI            24.0                 15.0            19.0
# 26              PIT            19.0                 18.0            26.0
# 27              SEA            21.0                 17.0            20.0
# 28               SF            20.0                 15.0            12.0
# 29               TB            36.0                  2.0             5.0
# 30              TEN            24.0                  6.0            13.0
# 31              WAS            32.0                  6.0             7.0
#
# Location Cover  Home Favorite Cover  PUSH  Total
# 0                              28.0   2.0   74.0
# 1                              21.0   2.0   76.0
# 2                              17.0   6.0   80.0
# 3                              32.0   3.0   73.0
# 4                              20.0   3.0   75.0
# 5                              26.0   1.0   72.0
# 6                              20.0   6.0   75.0
# 7                              34.0   5.0   72.0
# 8                              18.0   3.0   74.0
# 9                              19.0   2.0   73.0
# 10                             24.0   3.0   75.0
# 11                             18.0   3.0   81.0
# 12                             28.0   5.0   75.0
# 13                             26.0   4.0   78.0
# 14                             30.0   4.0   74.0
# 15                             21.0   2.0   75.0
# 16                             15.0   2.0   76.0
# 17                             28.0   2.0   73.0
# 18                             32.0   0.0   73.0
# 19                             24.0   3.0   74.0
# 20                              4.0   1.0   76.0
# 21                             15.0   0.0   77.0
# 22                             23.0   4.0   76.0
# 23                             30.0   7.0   75.0
# 24                             29.0   1.0   73.0
# 25                             17.0   0.0   75.0
# 26                             13.0   2.0   78.0
# 27                             18.0   5.0   81.0
# 28                             26.0   3.0   76.0
# 29                             27.0   2.0   72.0
# 30                             29.0   2.0   74.0
# 31                             27.0   0.0   72.0

# %%
away_dog_perc =away_team["Home Dog Cover"] / (away_team["Away Favorite Cover"] + away_team["Home Dog Cover"]) * 100
away_fav_perc = away_team["Home Favorite Cover"] / (away_team["Away Dog Cover"] + away_team["Home Favorite Cover"]) * 100

# %%
cover_percents_away = pd.DataFrame({"Away Team": away_team[""],
                                    "Away Dog %": away_dog_perc,
                                    "Away Favorite %": away_fav_perc,
                                    "Home Dog %": 100 - away_fav_perc,
                                    "Home Favorite %": 100 - away_dog_perc})
cover_percents_away
# Out:
#    Away Team  Away Dog %  Away Favorite %  Home Dog %  Home Favorite %
# 0        ARI   45.000000        53.846154   46.153846        55.000000
# 1        ATL   51.428571        53.846154   46.153846        48.571429
# 2        BAL   53.333333        38.636364   61.363636        46.666667
# 3        BUF   63.636364        54.237288   45.762712        36.363636
# 4        CAR   62.962963        44.444444   55.555556        37.037037
# 5        CHI   47.058824        48.148148   51.851852        52.941176
# 6        CIN   40.909091        42.553191   57.446809        59.090909
# 7        CLE   40.000000        54.838710   45.161290        60.000000
# 8        DAL   46.428571        41.860465   58.139535        53.571429
# 9        DEN   44.736842        57.575758   42.424242        55.263158
# 10       DET   62.500000        50.000000   50.000000        37.500000
# 11        GB   47.727273        52.941176   47.058824        52.272727
# 12       HOU   47.619048        57.142857   42.857143        52.380952
# 13       IND   45.454545        50.000000   50.000000        54.545455
# 14       JAX   55.555556        49.180328   50.819672        44.444444
# 15        KC   33.333333        45.652174   54.347826        66.666667
# 16       LAC   57.692308        31.250000   68.750000        42.307692
# 17       LAR   47.368421        53.846154   46.153846        52.631579
# 18       MIA   53.846154        53.333333   46.666667        46.153846
# 19       MIN   50.000000        47.058824   52.941176        50.000000
# 20        NE   48.333333        26.666667   73.333333        51.666667
# 21        NO   56.410256        39.473684   60.526316        43.589744
# 22       NYG   47.368421        43.396226   56.603774        52.631579
# 23       NYJ   47.368421        61.224490   38.775510        52.631579
# 24       OAK   62.500000        45.312500   54.687500        37.500000
# 25       PHI   55.882353        41.463415   58.536585        44.117647
# 26       PIT   59.090909        40.625000   59.375000        40.909091
# 27       SEA   54.054054        46.153846   53.846154        45.945946
# 28        SF   44.444444        56.521739   43.478261        55.555556
# 29        TB   71.428571        42.857143   57.142857        28.571429
# 30       TEN   68.421053        54.716981   45.283019        31.578947
# 31       WAS   53.846154        45.762712   54.237288        46.153846

# %%
cover_percents2_away = pd.DataFrame.round(cover_percents_away.copy(), 2)
cover_perc_columns_away = list(cover_percents2_away.columns)
for i in range(1, len(cover_perc_columns_away)):
    cover_percents2_away[cover_perc_columns_away[i]] = cover_percents2_away[cover_perc_columns_away[i]].astype(str) + '%'
cover_percents2_away
# Out:
#    Away Team Away Dog % Away Favorite % Home Dog % Home Favorite %
# 0        ARI      45.0%          53.85%     46.15%           55.0%
# 1        ATL     51.43%          53.85%     46.15%          48.57%
# 2        BAL     53.33%          38.64%     61.36%          46.67%
# 3        BUF     63.64%          54.24%     45.76%          36.36%
# 4        CAR     62.96%          44.44%     55.56%          37.04%
# 5        CHI     47.06%          48.15%     51.85%          52.94%
# 6        CIN     40.91%          42.55%     57.45%          59.09%
# 7        CLE      40.0%          54.84%     45.16%           60.0%
# 8        DAL     46.43%          41.86%     58.14%          53.57%
# 9        DEN     44.74%          57.58%     42.42%          55.26%
# 10       DET      62.5%           50.0%      50.0%           37.5%
# 11        GB     47.73%          52.94%     47.06%          52.27%
# 12       HOU     47.62%          57.14%     42.86%          52.38%
# 13       IND     45.45%           50.0%      50.0%          54.55%
# 14       JAX     55.56%          49.18%     50.82%          44.44%
# 15        KC     33.33%          45.65%     54.35%          66.67%
# 16       LAC     57.69%          31.25%     68.75%          42.31%
# 17       LAR     47.37%          53.85%     46.15%          52.63%
# 18       MIA     53.85%          53.33%     46.67%          46.15%
# 19       MIN      50.0%          47.06%     52.94%           50.0%
# 20        NE     48.33%          26.67%     73.33%          51.67%
# 21        NO     56.41%          39.47%     60.53%          43.59%
# 22       NYG     47.37%           43.4%      56.6%          52.63%
# 23       NYJ     47.37%          61.22%     38.78%          52.63%
# 24       OAK      62.5%          45.31%     54.69%           37.5%
# 25       PHI     55.88%          41.46%     58.54%          44.12%
# 26       PIT     59.09%          40.62%     59.38%          40.91%
# 27       SEA     54.05%          46.15%     53.85%          45.95%
# 28        SF     44.44%          56.52%     43.48%          55.56%
# 29        TB     71.43%          42.86%     57.14%          28.57%
# 30       TEN     68.42%          54.72%     45.28%          31.58%
# 31       WAS     53.85%          45.76%     54.24%          46.15%

# %%
a_away = cover_percents_away.iloc[0, 1]
b_away = cover_percents_away.iloc[0, 2]
c_away = cover_percents_away.iloc[0, 3]
d_away = cover_percents_away.iloc[0, 4]
# Washington individual stats
e_away = cover_percents_away.iloc[31, 1]
f_away = cover_percents_away.iloc[31, 2]
g_away = cover_percents_away.iloc[31, 3]
h_away = cover_percents_away.iloc[31, 4]
# New England individual stats
i_away = cover_percents_away.iloc[20, 1]
j_away = cover_percents_away.iloc[20, 2]
k_away = cover_percents_away.iloc[20, 3]
l_away = cover_percents_away.iloc[20, 4]
awaydog_away = [a_away,e_away,i_away]
awayfav_away = [b_away,f_away,j_away]
homedog_away = [c_away,g_away,k_away]
homefav_away = [d_away,h_away,l_away]
index = ['Arizona','Washington','New England']
df_away = pd.DataFrame({'Home Dog %': homedog_away,
                        'Home Fav %': homefav_away,
                        'Away Dog %': awaydog_away,
                        'Away Fav %': awayfav_away}, index=index)
chart_away = df_away.plot.bar(figsize=(20, 10), rot=0)
